# %%
"""
Created on Tue May  5 10:19:08 2020

@author: josephkarpinski
"""

# %% [markdown]
# https://www.sdss.org/dr16/irspec/targets/special-programs/
#
# https://www.sdss.org/dr16/irspec/targets/

# %%
print("\nSection 001 ########################################################################\n")

from http.client import BAD_REQUEST
import sys

from scipy.fftpack import fft
print(sys.executable)


# set the path to the folder containing downloaded starcolorindexSpT.py file 
sys.path.insert(1,'/Users/josephkarpinski')

import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

import scipy as sp

from scipy import *


import seaborn as sns 
#from mpl_toolkits import mplot3d
from scipy.stats import gaussian_kde

import starcolorindexSpT

import ipywidgets as widgets

#import ApogeeFunctionsNewCSV as ap

pd.set_option('display.max_rows', 2000)


print("\nInitialize!")

# %%
Ipython_default = plt.rcParams.copy()

# reset rcParams
#plt.rcParams.update(Ipython_default)

plt.style.use('dark_background')

print("Backup default plot background. \nSet Dark background.")

# %%
# Set the path to the downloaded Globular_Clusters.csv and read into the Python DatFrame df_Apogee
#df_Apogee = pd.read_csv('/Users/josephkarpinski/Downloads/Globular_Clusters.csv')
#df_Apogee = pd.read_csv('/Users/josephkarpinski/Downloads/Globular_Clusters_Full.csv')

#df_Apogee = pd.read_csv('/Users/josephkarpinski/allStarLite-r12-133.csv')
df_Apogee = pd.read_csv('/Users/josephkarpinski/allStar-r12-133.CSV')


# Sort and display data columns
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 2000)

df_Apogee .columns.sort_values().tolist()

# %%
# Use BP_RP value to group stars into classes

df_Apogee['BP_RP']   = df_Apogee['GAIA_PHOT_BP_MEAN_MAG']  - df_Apogee['GAIA_PHOT_RP_MEAN_MAG']
df_Apogee['SpT2'] = df_Apogee.apply(lambda row: starcolorindexSpT.subclass[round(row.BP_RP, 2)], axis=1)
df_Apogee['LightYears'] =  abs(((1 / df_Apogee['GAIA_PARALLAX']) * 3.26 * 1000))
df_Apogee['Parsec'] =  abs(((1 / df_Apogee['GAIA_PARALLAX']) * 1000))
df_Apogee['Kpc'] =  abs(((1 / df_Apogee['GAIA_PARALLAX'])))

df_Apogee['M'] = df_Apogee['GAIA_PHOT_G_MEAN_MAG'] + 5*np.log10(df_Apogee['GAIA_PARALLAX']) - 10

df_Apogee['LY'] = abs(3261.56/df_Apogee['GAIA_PARALLAX'])

df_Apogee['L_sun'] = np.power(10,[(4.77-m)/2.5 for m in df_Apogee['M']])

df_Apogee['T_K'] = [5601/np.power(c+0.4,2/3) for c in df_Apogee['BP_RP']]

df_Apogee['R_sun']=np.around(np.sqrt(df_Apogee['L_sun'])/(df_Apogee['T_K']/5800)**2, decimals=2) # T_☉ = 5800

df_class_O = df_Apogee[(df_Apogee['SpT2'] >= "O0V") & (df_Apogee['SpT2'] <= "O9V")]
df_class_B = df_Apogee[(df_Apogee['SpT2'] >= "B0V") & (df_Apogee['SpT2'] <= "B9V")]
df_class_A = df_Apogee[(df_Apogee['SpT2'] >= "A0V") & (df_Apogee['SpT2'] <= "A9V")]
df_class_F = df_Apogee[(df_Apogee['SpT2'] >= "F0V") & (df_Apogee['SpT2'] <= "F9V")]
df_class_G = df_Apogee[(df_Apogee['SpT2'] >= "G0V") & (df_Apogee['SpT2'] <= "G9V")]
df_class_K = df_Apogee[(df_Apogee['SpT2'] >= "K0V") & (df_Apogee['SpT2'] <= "K9V")]
df_class_M = df_Apogee[(df_Apogee['SpT2'] >= "M0V") & (df_Apogee['SpT2'] <= "M9V")]
df_class_L = df_Apogee[(df_Apogee['SpT2'] >= "L0V") & (df_Apogee['SpT2'] <= "L9V")]
df_class_T = df_Apogee[(df_Apogee['SpT2'] >= "T0V") & (df_Apogee['SpT2'] <= "T9V")]

print("\nClass O: " + str(df_class_O.shape[0]))
print("Class B: " + str(df_class_B.shape[0]))
print("Class A: " + str(df_class_A.shape[0]))
print("Class F: " + str(df_class_F.shape[0]))
print("Class G: " + str(df_class_G.shape[0]))
print("Class K: " + str(df_class_K.shape[0]))
print("Class M: " + str(df_class_M.shape[0]))
print("Class L: " + str(df_class_L.shape[0]))
print("Class T: " + str(df_class_T.shape[0]))

s1 = df_Apogee

Fd1 = s1[s1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
GKd1 = s1[s1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
GKg1 = s1[s1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
Md1 = s1[s1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
Mg1 = s1[s1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]

print("\nFd: " + str(Fd1.shape[0]))
print("GKd: " + str(GKd1.shape[0]))
print("GKg: " + str(GKg1.shape[0]))
print("Md: " + str(Md1.shape[0]))
print("Mg: " + str(Mg1.shape[0]))


idx_BA  = sp.where( (s1['ASPCAP_CLASS'] == 'BA') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

idx_Fd_a = sp.where( (s1['ASPCAP_CLASS'] == 'Fd_a') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Fd_b = sp.where( (s1['ASPCAP_CLASS'] == 'Fd_b') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Fd_c = sp.where( (s1['ASPCAP_CLASS'] == 'Fd_c') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Fd_d = sp.where( (s1['ASPCAP_CLASS'] == 'Fd_d') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

idx_GKd_a = sp.where( (s1['ASPCAP_CLASS'] == 'GKd_a') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKd_b = sp.where( (s1['ASPCAP_CLASS'] == 'GKd_b') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKd_c = sp.where( (s1['ASPCAP_CLASS'] == 'GKd_c') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKd_d = sp. where( (s1['ASPCAP_CLASS'] == 'GKd_d') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

idx_GKg_a = sp.where( (s1['ASPCAP_CLASS'] == 'GKg_a') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKg_b = sp.where( (s1['ASPCAP_CLASS'] == 'GKg_b') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKg_c = sp.where( (s1['ASPCAP_CLASS'] == 'GKg_c') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_GKg_d = sp.where( (s1['ASPCAP_CLASS'] == 'GKg_d') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

idx_Md_b = sp.where( (s1['ASPCAP_CLASS'] == 'Md_b') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Md_c = sp.where( (s1['ASPCAP_CLASS'] == 'Md_c') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Md_d = sp.where( (s1['ASPCAP_CLASS'] == 'Md_d') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Md_a = sp.where( (s1['ASPCAP_CLASS'] == 'Md_a') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

idx_Mg_a = sp.where( (s1['ASPCAP_CLASS'] == 'Mg_a') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Mg_b = sp.where( (s1['ASPCAP_CLASS'] == 'Mg_b') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Mg_c = sp.where( (s1['ASPCAP_CLASS'] == 'Mg_c') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]
idx_Mg_d = sp.where( (s1['ASPCAP_CLASS'] == 'Mg_d') & sp.logical_not (s1['APOGEE_TARGET2'] & 2**9))[0]

s1Label = "All"

print('\n' + s1Label + ': Stars '   + str(s1.shape[0]))

print('\nBA' + ': Stars '   + str(idx_BA.shape[0]))

print('\nFd_a' + ': Stars '   + str(idx_Fd_a.shape[0]))
print('Fd_b' + ': Stars '     + str(idx_Fd_b.shape[0]))
print('Fd_c' + ': Stars '     + str(idx_Fd_c.shape[0]))
print('Fd_d' + ': Stars '     + str(idx_Fd_d.shape[0]))


print('\nGKd_a' + ': Stars '   + str(idx_GKd_a.shape[0]))
print('GKd_b' + ': Stars '     + str(idx_GKd_b.shape[0]))
print('GKd_c' + ': Stars '     + str(idx_GKd_c.shape[0]))
print('GKd_d' + ': Stars '     + str(idx_GKd_d.shape[0]))


print('\nGKg_a' + ': Stars '   + str(idx_GKg_a.shape[0]))
print('GKg_b' + ': Stars '     + str(idx_GKg_b.shape[0]))
print('GKg_c' + ': Stars '     + str(idx_GKg_c.shape[0]))
print('GKg_d' + ': Stars '     + str(idx_GKg_d.shape[0]))


print('\nMd_a' + ': Stars '   + str(idx_Md_a.shape[0]))
print('Md_b' + ': Stars '     + str(idx_Md_b.shape[0]))
print('Md_c' + ': Stars '     + str(idx_Md_c.shape[0]))
print('Md_d' + ': Stars '     + str(idx_Md_d.shape[0]))


print('\nMg_a' + ': Stars '   + str(idx_Mg_a.shape[0]))
print('Mg_b' + ': Stars '     + str(idx_Mg_b.shape[0]))
print('Mg_c' + ': Stars '     + str(idx_Mg_c.shape[0]))
print('Mg_d' + ': Stars '     + str(idx_Mg_d.shape[0]))

# %%
def Plot001(f1):
    if Display_Plot_Indicator == "Y":
        print("\nPlot 001 ####################### HR Diagram")

    r0 = f1[f1.R_sun > 0]
    rr1 = r0[r0.R_sun < 150]

    plt.style.use('dark_background')
    sns.relplot(x='BP_RP', y='M', height=8.5, aspect=1.2, legend=None,
                hue='BP_RP',
                palette='RdYlBu_r',
                size='R_sun',
                sizes=(1,rr1['R_sun'].max()/rr1['R_sun'].min()),
                data=rr1
                )
    plt.ylim(rr1['M'].max()+1, rr1['M'].min()-1)
    plt.xlabel('Color (bp - rp)', fontsize=15)
    plt.ylabel('Absolute Magnitude', fontsize=15)
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    plt.show() 


def Plot002(f1):
    if Display_Plot_Indicator == "Y":
        print("\nPlot 002 ####################### HR Diagram Mapping BP-RP")

    plt.style.use('dark_background')
    s0 = f1[f1['LOGG'] > 0]
    s1 = s0[s0['GAIA_PHOT_G_MEAN_MAG'] > -9999]
    ff1 = s1[(s1['BP_RP'] > -9999) & (s1['BP_RP'] < 9999)]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['BP_RP'], BA1['M'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=30,c='violet')
    plt.scatter(Fd1['BP_RP'], Fd1['M'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['BP_RP'], GKd1['M'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['BP_RP'], GKg1['M'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['BP_RP'], Mg1['M'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['BP_RP'], Md1['M'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    plt.gca().invert_yaxis()
    plt.xlabel('BP_RP', fontsize=15)
    plt.ylabel('Absolute Magnitude', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    plt.show() 
    

def Plot003(f1):
    if Display_Plot_Indicator == "Y":
        print("\nPlot 003 ####################### HR Diagram Mapping BP-RP")

    plt.style.use('dark_background')
    s0 = f1[f1['LOGG'] > 0]
    s1 = s0[s0['GAIA_PHOT_G_MEAN_MAG'] > -9999]
    ff1 = s1[(s1['BP_RP'] > -9999) & (s1['BP_RP'] < 9999)]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['BP_RP'], ff1['M'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.LOGG,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_yaxis()
    plt.xlabel('BP_RP', fontsize=15)
    plt.ylabel('Absolute Magnitude', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("LogG",size=15)
    plt.show() 
    
         
def Plot004(f1):
    if Display_Plot_Indicator == "Y":
        print("\nPlot 004 ####################### HR Diagram Mapping Star Class \n")

    plt.style.use('dark_background')
    s0 = f1[f1['LOGG'] > 0]
    s1 = s0[s0['GAIA_PHOT_G_MEAN_MAG'] > -9999]
    ff1 = s1[(s1['BP_RP'] > -9999) & (s1['BP_RP'] < 9999)]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['BP_RP'], BA1['GAIA_PHOT_G_MEAN_MAG'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=30,c='violet')
    plt.scatter(Fd1['BP_RP'], Fd1['GAIA_PHOT_G_MEAN_MAG'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['BP_RP'], GKd1['GAIA_PHOT_G_MEAN_MAG'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['BP_RP'], GKg1['GAIA_PHOT_G_MEAN_MAG'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['BP_RP'], Mg1['GAIA_PHOT_G_MEAN_MAG'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['BP_RP'], Md1['GAIA_PHOT_G_MEAN_MAG'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    plt.gca().invert_yaxis()
    plt.xlabel('BP_RP', fontsize=15)
    plt.ylabel('GAIA_PHOT_G_MEAN_MAG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    plt.show() 
    

def Plot005(f1):
    if Display_Plot_Indicator == "Y":
        print("Plot 005 ####################### HR Diagram Mapping Star Class")

    plt.style.use('dark_background')
    s0 = f1[f1['M_H'] > -9999]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['TEFF'], BA1['LOGG'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=25,c='b')
    plt.scatter(Fd1['TEFF'], Fd1['LOGG'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['TEFF'], GKd1['LOGG'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['TEFF'], GKg1['LOGG'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['TEFF'], Mg1['LOGG'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['TEFF'], Md1['LOGG'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    plt.show() 
    

def Plot006(f1):
    if Display_Plot_Indicator == "Y":
        print("\nPlot 006 ####################### HR Diagram Mapping Metal Content \n")

    plt.style.use('dark_background')
    s0 = f1[f1['M_H'] > -9999]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.M_H,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Total Metal Content [M/H]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Total Metal Content [M/H]",size=15)
    plt.show() 
     

def Plot007(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007 ####################### HR Diagram Mapping Alpha-Element Abundance \n")

    s0 = f1[f1['ALPHA_M'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.ALPHA_M,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' + 
    '[ALPHA_M] defined as O, Mg, Si, S, Ca and Ti', fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Alpha-Element Abundance [ALPHA_M]",size=15)
    plt.show() 


def Plot007A(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007A ####################### HR Diagram Mapping Fe_H \n")

    s0 = f1[f1['FE_H'] >= -9999]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.FE_H,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' + 
    '[FE_H]', fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("[FE_H]",size=15)
    plt.show() 
     
def Plot007B(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007B ####################### HR Diagram Mapping [C/M] \n")

    s0 = f1[f1['param_c_m'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.param_c_m,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Carbon Abundance [C/M]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Carbon Abundance [C/M]",size=15)
    plt.show() 


def Plot007C(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007C ####################### HR Diagram Mapping [N/M] \n")

    s0 = f1[f1['param_n_m'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.param_n_m,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Nitrogen Abundance [N/M]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Nitrogen Abundance [N/M]",size=15)
    plt.show() 


def Plot007D(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007D ####################### HR Diagram Mapping [VMICRO] \n")

    s0 = f1[f1['VMICRO'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.VMICRO,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Microturbulent Velocity [VMICRO]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Microturbulent Velocity [VMICRO]",size=15)
    plt.show() 


def Plot007E(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007E ####################### HR Diagram Mapping [VMICRO] \n")

    s0 = f1[f1['param_vsini_vmacro'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.param_vsini_vmacro,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Vsini Vmacro [vsini/macro]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Vsini Vmacro [vsini/macro]",size=15)
    plt.show() 


def Plot007F(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007F ####################### HR Diagram Mapping [VMICRO] \n")

    s0 = f1[(f1['VHELIO_AVG'] > -9999) & (f1['VHELIO_AVG'] < 9999)]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.VHELIO_AVG,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "Average Radial Velocity [VHELIO_AVG]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Average Radial Velocity [VHELIO_AVG]",size=15)
    plt.show() 
     

def Plot007G(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007G ####################### HR Diagram Mapping [Kpc] \n")

    s0 = f1[(f1['Kpc'] > 0) & (f1['Kpc'] < 4)]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.Kpc,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "[0 - 4] Kilo-Parsecs [Kpc]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Kilo-Parsecs [Kpc]",size=15)
    plt.show() 

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007G ####################### HR Diagram Mapping [Kpc] \n")

    s0 = f1[(f1['Kpc'] >=4) & (f1['Kpc'] < 8)]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.Kpc,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "[4 - 8] Kilo-Parsecs [Kpc]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Kilo-Parsecs [Kpc]",size=15)
    plt.show() 

    if Display_Plot_Indicator == "Y":
        print("\nPlot 007G ####################### HR Diagram Mapping [Kpc] \n")

    s0 = f1[(f1['Kpc'] >= 8) & (f1['Kpc'] < 15)]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.Kpc,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram\n' +
    "[8 - 15] Kilo-Parsecs [Kpc]", fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Kilo-Parsecs [Kpc]",size=15)
    plt.show() 


def Plot008(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 008 ####################### HR Diagram Mapping SFD reddening \n")

    s0 = f1[f1['SFD_EBV'] >= 0]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[s1['LOGG'] > -9999]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.SFD_EBV,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("SFD Reddening [SFD_EBV]",size=15)
    plt.show() 
    

def Plot009(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 009 ####################### HR Diagram Mapping BP-RP \n")

    s0 = f1[f1['LOGG'] > -9999]
    s1 = s0[s0['TEFF'] > -9999]
    ff1 = s1[(s1['BP_RP'] > -9999) & (s1['BP_RP'] < 9999)]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
    c=ff1.BP_RP,edgecolor='k',cmap="jet")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.title(str(field) + '\nHertzsprung-Russel Diagram', fontsize=15)
    bar = fig.colorbar(image,orientation="vertical",pad=0.01)
    bar.set_label("Gaia Color [BP_RP]",size=15)
    plt.show()


def Plot010(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 010 ####################### VHELIO_AVG \n")

    ff1 = f1[(f1['VHELIO_AVG'] > -9999) & (f1['VHELIO_AVG'] < 9999)]
    s1Label = "VHELIO_AVG"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if ff1['RA'].min() > 50:
        image = plt.scatter(ff1['RA'], ff1['DEC'], label=s1Label, marker='o', linewidth=0,
        c=ff1.VHELIO_AVG,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('RA', fontsize=15)
        plt.ylabel('DEC', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nAverage Radial Velocity [VHELIO_AVG] \nMin: " + str(int(ff1.VHELIO_AVG.min())) +
        "    Avg: " + str(int(ff1.VHELIO_AVG.mean())) +
        "    Max: " + str(int(ff1.VHELIO_AVG.max())), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("VHELIO_AVG",size=15)
        plt.show() 
    else:
        image = plt.scatter(ff1['GLON'], ff1['GLAT'], label=s1Label, marker='o', linewidth=0,
        c=ff1.VHELIO_AVG,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('GLON', fontsize=15)
        plt.ylabel('GLAT', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nVHELIO_AVG \nMin: " + str(int(ff1.VHELIO_AVG.min())) +
        "    Avg: " + str(int(ff1.VHELIO_AVG.mean())) +
        "    Max: " + str(int(ff1.VHELIO_AVG.max())), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("VHELIO_AVG",size=15)
        plt.show()


def Plot011(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 011 ####################### Gaia Radial Velocity \n")

    ff1 = f1[f1['GAIA_RADIAL_VELOCITY'] > -9999]
    s1Label = "GAIA_RADIAL_VELOCITY"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if ff1['RA'].min() > 50:
        image = plt.scatter(ff1['RA'], ff1['DEC'], label=s1Label, marker='o', linewidth=0,
        c=ff1.GAIA_RADIAL_VELOCITY,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('RA', fontsize=15)
        plt.ylabel('DEC', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nRadial Velocity \nMin: " + str(int(ff1.GAIA_RADIAL_VELOCITY.min())) +
        "    Avg: " + str(int(ff1.GAIA_RADIAL_VELOCITY.mean())) +
        "    Max: " + str(int(ff1.GAIA_RADIAL_VELOCITY.max())), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("GAIA_RADIAL_VELOCITY",size=15)
        plt.show() 
    else:
        image = plt.scatter(ff1['GLON'], ff1['GLAT'], label=s1Label, marker='o', linewidth=0,
        c=ff1.GAIA_RADIAL_VELOCITY,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('GLON', fontsize=15)
        plt.ylabel('GLAT', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nRadial Velocity \nMin: " + str(int(ff1.GAIA_RADIAL_VELOCITY.min())) +
        "    Avg: " + str(int(ff1.GAIA_RADIAL_VELOCITY.mean())) +
        "    Max: " + str(int(ff1.GAIA_RADIAL_VELOCITY.max())), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("GAIA_RADIAL_VELOCITY",size=15)
        plt.show()


def Plot012(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 012 ####################### LogG \n")

    ff1 = f1[f1['LOGG'] > -9999]
    s1Label = "LogG"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if ff1['RA'].min() > 50:
        image = plt.scatter(ff1['RA'], ff1['DEC'], label=s1Label, marker='o', linewidth=0,
        c=ff1.LOGG,edgecolor='k',cmap="jet")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('RA', fontsize=15)
        plt.ylabel('DEC', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + "  \nAverage LogG: " + str(round(ff1.LOGG.mean(),2)), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("LogG",size=15)
        plt.show()
    else:
        image = plt.scatter(ff1['GLON'], ff1['GLAT'], label=s1Label, marker='o', linewidth=0,
        c=ff1.LOGG,edgecolor='k',cmap="jet")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('GLON', fontsize=15)
        plt.ylabel('GLAT', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + "  \nAverage LogG: " + str(round(ff1.LOGG.mean(),2)), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("LogG",size=15)
        plt.show()


def Plot013(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 013 ####################### LogG Heatmap \n")

    rAscap = 'All'
    idx1 = f1['LOGG'] > -9999
    dfs1 = f1[idx1]
    dfs1['LOGG_round'] = round(dfs1['LOGG'], 2)
    if rAscap == 'All':
        dfs3 = dfs1
    else:
        idx2 = dfs1['ASPCAP_CLASS'] == rAscap
        dfs3 = dfs1[idx2]
    
    dfs3 = dfs3.sort_values(by=['LOGG'], ascending=True)
    dfs2 = dfs3.drop_duplicates(subset=['APOGEE_ID'], keep='first')
    
    if dfs2.shape[0] > 25:
        if dfs2.shape[0] > 50:
            df_list = dfs2[:50]
        else:
            df_list = dfs2[:25]
        s1_temp = df_list.pivot(index='APOGEE_ID', columns='SpT2', values='LOGG_round') #good
        
        result = s1_temp.fillna(value=0)
        
        # Draw a heatmap with the numeric values in each cell
        f, ax = plt.subplots(figsize=(20, 15))
        
        plt.title(str(field) +  "\n LogG" , fontsize=15)
        plt.xticks(fontsize=15)
        plt.yticks(fontsize=15)
        
        cmap = sns.cm.rocket_r 
        
        heat_map = sns.heatmap(result, annot=True, fmt="g", cmap='jet', linewidths=.5, ax=ax,
                    cbar_kws={'label': 'LogG'})
        heat_map.figure.axes[-1].yaxis.label.set_size(18)
        plt.show()


def Plot014(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 014 ####################### FeH \n")

    ff1 = f1[f1['FE_H'] > -9999]
    s1Label = "FE_H"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if ff1['RA'].min() > 50:
        image = plt.scatter(ff1['RA'], ff1['DEC'], label=s1Label, marker='o', linewidth=0,
                    c=ff1.FE_H,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('RA', fontsize=15)
        plt.ylabel('DEC', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nMinimum FeH: " + str(round(ff1.FE_H.min(),2)) +
        "    Average FeH: " + str(round(ff1.FE_H.mean(),2)), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label('FeH',size=15)
        plt.show()
    else:
        image = plt.scatter(ff1['GLON'], ff1['GLAT'], label=s1Label, marker='o', linewidth=0,
                    c=ff1.FE_H,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_yaxis()
        plt.xlabel('GLON', fontsize=15)
        plt.ylabel('GLAT', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "  \nMinimum FeH: " + str(round(ff1.FE_H.min(),2)) +
        "    Average FeH: " + str(round(ff1.FE_H.mean(),2)), fontsize=18)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label('FeH',size=15)
        plt.show()


def Plot015(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 015 ####################### FeH Heatmap \n")

    rAscap == 'All'
    idx1 = f1['FE_H'] > -9999
    dfs1 = f1[idx1]
    dfs1['FE_H_round'] = round(dfs1['FE_H'], 2)
    if rAscap == 'All':
        dfs3 = dfs1
    else:
        idx2 = dfs1['ASPCAP_CLASS'] == rAscap
        dfs3 = dfs1[idx2]
    
    dfs3 = dfs3.sort_values(by=['FE_H'], ascending=True)
    
    dfs2 = dfs3.drop_duplicates(subset=['APOGEE_ID'], keep='first')
    
    if dfs2.shape[0] > 25:
        if dfs2.shape[0] > 50:
            df_list = dfs2[:50]
        else:
            df_list = dfs2[:25]
        df_list = df_list.sort_values(by=['APOGEE_ID'], ascending=True)
        s1_temp = df_list.pivot(index='APOGEE_ID', columns='SpT2', values='FE_H_round')
        result = s1_temp.fillna(value=0)
        sns.set()
        # Draw a heatmap with the numeric values in each cell
        f, ax = plt.subplots(figsize=(20, 15))
        plt.title(str(field) +  "\n FE_H", fontsize=15)
        plt.xticks(fontsize=15)
        plt.yticks(fontsize=15)
        
        cmap = sns.cm.rocket_r #jet_r
        
        heat_map = sns.heatmap(result, annot=True, fmt="g", cmap='jet_r', linewidths=.5, ax=ax,
                    cbar_kws={'label': 'FeH'})
        heat_map.figure.axes[-1].yaxis.label.set_size(18)
        plt.show()



def Plot020(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 020 ####################### AL_Fe vs N_Fe \n")

    s0 = f1[f1['N_FE'] >= 0]
    ff1 = s0[s0['AL_FE'] >= 0]
    #ff1 = s1[s1['LOGG'] > -9999]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['N_FE'], BA1['AL_FE'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=25,c='b')
    plt.scatter(Fd1['N_FE'], Fd1['AL_FE'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['N_FE'], GKd1['AL_FE'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['N_FE'], GKg1['AL_FE'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['N_FE'], Mg1['AL_FE'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['N_FE'], Md1['AL_FE'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    #plt.gca().invert_xaxis()
    #plt.gca().invert_yaxis()
    plt.xlabel('N_FE', fontsize=15)
    plt.ylabel('AL_FE', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + 
    "\nRelative Abundance Diagram \n[AL_FE]-[N_FE]", fontsize=15)
    plt.show() 
    

def Plot020B(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 020B ####################### AL_Fe vs N_Fe Bar FE_H\n")

    #f0 = f1[(f1['AL_FE'] >= 0) & (f1['AL_FE'] <= 1)]
    s0 = f1[f1['N_FE'] >= 0]
    f0 = s0[(s0['AL_FE'] >= 0) & (s0['AL_FE'] <= 1)]

    if f0.shape[0] > 0:
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(f0['N_FE'], f0['AL_FE'], label=s1Label, marker='o', linewidth=0,s=20,
        c=f0.FE_H,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        #plt.gca().invert_xaxis()
        #plt.gca().invert_yaxis()
        plt.xlabel('N_FE', fontsize=15)
        plt.ylabel('AL_FE', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "\nRelative Abundance Diagram \n[AL_FE]-[N_FE]", fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("Fe/H",size=15)
        plt.show()

   
def Plot021(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 021 ####################### C_Fe vs N_Fe \n")

    s0 = f1[f1['N_FE'] >= 0]
    ff1 = s0[s0['C_FE'] >= 0]
    #ff1 = s1[s1['LOGG'] > -9999]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['N_FE'], BA1['C_FE'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=25,c='b')
    plt.scatter(Fd1['N_FE'], Fd1['C_FE'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['N_FE'], GKd1['C_FE'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['N_FE'], GKg1['C_FE'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['N_FE'], Mg1['C_FE'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['N_FE'], Md1['C_FE'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    #plt.gca().invert_xaxis()
    #plt.gca().invert_yaxis()
    plt.xlabel('N_FE', fontsize=15)
    plt.ylabel('C_FE', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + 
    "\nRelative Abundance Diagram \n[C_FE]-[N_FE]", fontsize=15)
    plt.show() 
    

def Plot021B(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 021B ####################### C_Fe vs N_Fe Bar FE_H\n")

    #f0 = f1[(f1['AL_FE'] >= 0) & (f1['AL_FE'] <= 1)]
    s0 = f1[f1['N_FE'] >= 0]
    f0 = s0[(s0['AL_FE'] >= 0) & (s0['AL_FE'] <= 1)]

    if f0.shape[0] > 0:
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(f0['N_FE'], f0['C_FE'], label=s1Label, marker='o', linewidth=0,s=20,
        c=f0.FE_H,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        #plt.gca().invert_xaxis()
        #plt.gca().invert_yaxis()
        plt.xlabel('N_FE', fontsize=15)
        plt.ylabel('C_FE', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "\nRelative Abundance Diagram \n[C_FE]-[N_FE]", fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("Fe/H",size=15)
        plt.show()


def Plot022(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 022 ####################### O_Fe vs N_Fe \n")
        
    s0 = f1[f1['N_FE'] >= 0]
    ff1 = s0[s0['O_FE'] >=0]
    #ff1 = s1[s1['LOGG'] > -9999]
    BA1 = ff1[ff1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1 = ff1[ff1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1 = ff1[ff1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1 = ff1[ff1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1 = ff1[ff1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    s1Label = "TEFF"
    fig = plt.figure(figsize=(15, 12))
    plt.subplot(111)
    if BA1.shape[0] > 0:
        plt.scatter(BA1['N_FE'], BA1['O_FE'], label=('BA stars: ' + str(BA1.shape[0])), marker='o', linewidth=0,s=25,c='b')
    plt.scatter(Fd1['N_FE'], Fd1['O_FE'], label=('Fd stars: ' + str(Fd1.shape[0])), marker='o', linewidth=0,s=20,c='b')
    plt.scatter(GKd1['N_FE'], GKd1['O_FE'], label=('GKd stars: ' + str(GKd1.shape[0])), marker='o', linewidth=0,s=20,c='g')
    plt.scatter(GKg1['N_FE'], GKg1['O_FE'], label=('GKg stars: ' + str(GKg1.shape[0])), marker='o', linewidth=0,s=20,c='orange')
    plt.scatter(Mg1['N_FE'], Mg1['O_FE'], label=('Mg stars: ' + str(Mg1.shape[0])), marker='o', linewidth=0,s=20,c='r')
    if Md1.shape[0] > 0:
        plt.scatter(Md1['N_FE'], Md1['O_FE'], label=('Md stars: ' + str(Md1.shape[0])), marker='o', linewidth=0,s=20,c='aqua')
    ax = plt.gca()
    #plt.gca().invert_xaxis()
    #plt.gca().invert_yaxis()
    plt.xlabel('N_FE', fontsize=15)
    plt.ylabel('O_FE', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title(str(field) + 
    "\nRelative Abundance Diagram \n[O_FE]-[N_FE]", fontsize=15)
    plt.show() 
    

def Plot022B(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 022B ####################### O_Fe vs N_Fe Bar FE_H\n")

    #f0 = f1[(f1['AL_FE'] >= 0) & (f1['AL_FE'] <= 1)]
    s0 = f1[f1['N_FE'] >= 0]
    f0 = s0[(s0['O_FE'] >= 0) & (s0['O_FE'] <= 1)]

    if f0.shape[0] > 0:
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(f0['N_FE'], f0['O_FE'], label=s1Label, marker='o', linewidth=0,s=20,
        c=f0.FE_H,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        #plt.gca().invert_xaxis()
        #plt.gca().invert_yaxis()
        plt.xlabel('N_FE', fontsize=15)
        plt.ylabel('O_FE', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + 
        "\nRelative Abundance Diagram \n[O_FE]-[N_FE]", fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("Fe/H",size=15)
        plt.show()
    

def Plot030(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 030 ####################### ['AL_FE'] \n")

    f0 = f1[(f1['AL_FE'] >= 0) & (f1['AL_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.AL_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("AL_FE",size=15)
        plt.show()

    """f0 = f1[f1['AL_FE'] > -9999]
    if f0.shape[0] > 0:
        f1 = f0[(f0['BP_RP'] > -9999) & (f0['BP_RP'] < 9999)]
        ff1 = f1[f1['M'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['BP_RP'], ff1['M'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.AL_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        #plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('BP_RP', fontsize=15)
        plt.ylabel('Absolute Magnitude', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("AL_FE",size=15)
        plt.show()"""


def Plot031(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 031 ####################### ['C_FE'] \n")

    f0 = f1[(f1['C_FE'] >= 0) & (f1['C_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.C_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("C_FE",size=15)
        plt.show()


def Plot032(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 032 ####################### ['CA_FE'] \n")

    f0 = f1[(f1['CA_FE'] >= 0) & (f1['CA_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.CA_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("CA_FE",size=15)
        plt.show()


def Plot033(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 033 ####################### ['CI_FE'] \n")

    f0 = f1[(f1['CI_FE'] >= 0) & (f1['CI_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.CI_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("CI_FE",size=15)
        plt.show()


def Plot034(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 034 ####################### ['CO_FE'] \n")

    f0 = f1[(f1['CO_FE'] >= 0) & (f1['CO_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.CO_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("CO_FE",size=15)
        plt.show()


def Plot035(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 035 ####################### ['CR_FE'] \n")

    f0 = f1[(f1['CR_FE'] >= 0) & (f1['CR_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.CR_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("CR_FE",size=15)
        plt.show()


def Plot036(f1):
    plt.style.use('dark_background')

    if Display_Plot_Indicator == "Y":
        print("\nPlot 036 ####################### ['CU_FE'] \n")

    f0 = f1[(f1['CU_FE'] >= 0) & (f1['CU_FE'] <= 1)]
    if f0.shape[0] > 0:
        f1 = f0[f0['TEFF'] > -9999]
        ff1 = f1[f1['LOGG'] > -9999]
        s1Label = "TEFF"
        fig = plt.figure(figsize=(15, 12))
        plt.subplot(111)
        image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
        c=ff1.CU_FE,edgecolor='k',cmap="jet_r")
        ax = plt.gca()
        plt.gca().invert_xaxis()
        plt.gca().invert_yaxis()
        plt.xlabel('Teff', fontsize=15)
        plt.ylabel('LogG', fontsize=15)
        plt.xticks(size = 15)
        plt.yticks(size = 15)
        plt.grid()
        plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
        bar = fig.colorbar(image,orientation="vertical",pad=0.01)
        bar.set_label("CU_FE",size=15)
        plt.show()


def Plot037(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 037 ####################### ['GE_FE'] \n")

        f0 = f1[(f1['GE_FE'] >= 0) & (f1['GE_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.GE_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("GE_FE",size=15)
            plt.show()


def Plot038(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 038 ####################### ['K_FE'] \n")

        f0 = f1[(f1['K_FE'] >= 0) & (f1['K_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.K_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("K_FE",size=15)
            plt.show()


def Plot039(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 039 ####################### ['MG_FE'] \n")

        f0 = f1[(f1['MG_FE'] >= 0) & (f1['MG_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.MG_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("MG_FE",size=15)
            plt.show()


def Plot040(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 040 ####################### ['MN_FE'] \n")

        f0 = f1[(f1['MN_FE'] >= 0) & (f1['MN_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.MN_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("MN_FE",size=15)
            plt.show()


def Plot041(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 041 ####################### ['NA_FE'] \n")

        f0 = f1[(f1['NA_FE'] >= 0) & (f1['NA_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.NA_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("NA_FE",size=15)
            plt.show()


def Plot042(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 042 ####################### ['ND_FE'] \n")

        f0 = f1[(f1['ND_FE'] >= 0) & (f1['ND_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.ND_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("ND_FE",size=15)
            plt.show()
    

def Plot043(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 043 ####################### ['NI_FE'] \n")

        f0 = f1[(f1['NI_FE'] >= 0) & (f1['NI_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.NI_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("NI_FE",size=15)
            plt.show()


def Plot044(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 044 ####################### ['N_FE'] \n")

        f0 = f1[(f1['N_FE'] >= 0) & (f1['N_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.N_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("N_FE",size=15)
            plt.show()


def Plot045(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 045 ####################### ['O_FE'] \n")

        f0 = f1[(f1['O_FE'] >= 0) & (f1['O_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.O_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("O_FE",size=15)
            plt.show()


def Plot046(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 046 ####################### ['P_FE'] \n")

        f0 = f1[(f1['P_FE'] >= 0) & (f1['P_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.P_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("P_FE",size=15)
            plt.show()


def Plot047(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 047 ####################### ['RB_FE'] \n")

        f0 = f1[(f1['RB_FE'] >= 0) & (f1['RB_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.RB_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("RB_FE",size=15)
            plt.show()


def Plot048(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 048 ####################### ['S_FE'] \n")

        f0 = f1[(f1['S_FE'] >= 0) & (f1['S_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.S_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("S_FE",size=15)
            plt.show()


def Plot049(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 049 ####################### ['TI_FE'] \n")

        f0 = f1[(f1['TI_FE'] >= 0) & (f1['TI_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.TI_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("TI_FE",size=15)
            plt.show()


def Plot050(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 050 ####################### ['TIII_FE'] \n")

        f0 = f1[(f1['TIII_FE'] >= 0) & (f1['TIII_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.TIII_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("TIII_FE",size=15)
            plt.show()


def Plot051(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 051 ####################### ['V_FE'] \n")

        f0 = f1[(f1['V_FE'] >= 0) & (f1['V_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.V_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("V_FE",size=15)
            plt.show()


def Plot052(f1):
        plt.style.use('dark_background')

        if Display_Plot_Indicator == "Y":
            print("\nPlot 052 ####################### ['YB_FE'] \n")

        f0 = f1[(f1['YB_FE'] >= 0) & (f1['YB_FE'] <= 1)]
        if f0.shape[0] > 0:
            f1 = f0[f0['TEFF'] > -9999]
            ff1 = f1[f1['LOGG'] > -9999]
            s1Label = "TEFF"
            fig = plt.figure(figsize=(15, 12))
            plt.subplot(111)
            image = plt.scatter(ff1['TEFF'], ff1['LOGG'], label=s1Label, marker='o', linewidth=0,s=20,
            c=ff1.YB_FE,edgecolor='k',cmap="jet_r")
            ax = plt.gca()
            plt.gca().invert_xaxis()
            plt.gca().invert_yaxis()
            plt.xlabel('Teff', fontsize=15)
            plt.ylabel('LogG', fontsize=15)
            plt.xticks(size = 15)
            plt.yticks(size = 15)
            plt.grid()
            plt.title(str(field) + '\nHertzsprung-Russel Diagram \nStars: ' + str(f0.shape[0]), fontsize=15)
            bar = fig.colorbar(image,orientation="vertical",pad=0.01)
            bar.set_label("YB_FE",size=15)
            plt.show()

# %%
# Unique Star Fields: 1366 in Apogee DR16

# Unique Sample Star Fields
unique_fields = sp.unique(df_Apogee['FIELD'])

print("\nSample Fields: " + str(unique_fields.shape[0]))

# Group 1366 Star Fields in Full Apogee DR16 data file
unique_fields01 =  unique_fields[0:250]
unique_fields02 =  unique_fields[250:500]
unique_fields03 =  unique_fields[500:750]
unique_fields04 =  unique_fields[750:1000]
unique_fields05 =  unique_fields[1000:1150]
unique_fields06 =  unique_fields[1150:1367]

unique_fields00 =  unique_fields[0:5]

# %%
# Print unique fields in sample file
#print(unique_fields)

# %%
DR16_fields = """ 

'000+00-C', '000+02', '000+02-O', '000+04', '000+04-O', '000+05-O', '000+08', '000+08-S', '000+12', '000+14', '000+16', '000+17', 
'000+30', '000+45', '000+60', '000+75', '000-02', '000-02-O', '000-04', '000-04-O', '000-08', '000-12', '000-17-C', '001+01', 
'001-01', '001-01-O', '001-04-O', '001-05-O', '002+00', '002+00-C', '002+02-O', '002+04', '002+06', '002-02-O', '002-03-O', 
'002-04', '002-05-O', '002-06-O', '003+02', '003+02-O', '003+03-O', '003+05', '003-02-O', '003-03-C', '003-03-O', '003-05', 
'003-05-O', '004+00', '004+02', '004+02-O', '004+04', '004+05-O', '004-02', '004-02-O', '004-04', '005+00', '005+02-O', '005+03', 
'005+03-O', '005+04', '005+05-O', '005+08', '005-02', '005-03', '005-03-O', '006+00', '006+02', '006+04-O', '006+06', '006-02', 
'007+02-O', '007+07', '008+00', '008+02', '008-02', '009+09', '010+00', '010+02', '010+12', '010+60', '010-02', '010-07-C', 
'010-12', '011+47_btx', '011+79_MGA', '012+00', '012+02', '012-02', '013+00', '014+00', '014+02', '014+89_MGA', '014-02', 
'015+02', '015+12', '015+30', '015-12', '015-14', '016+00', '016+02', '016+77_MGA', '016-02', '018+00', '018+02', '018-02', 
'020+00', '020+02', '020+04', '020+06', '020+12', '020+14', '020+60', '020-02', '020-06', '020-12', '020-14', '021+79_MGA',
 '022+00', '022+02', '022+82_MGA', '022-02', '023+78_MGA', '023+88_MGA', '024+00', '024+03', '024-03', '025+06', '025+10', 
 '025+12', '025+14', '025-06', '025-10', '025-12', '025-14', '027+00', '027+04', '027-04', '029+77_MGA', '029+88_MGA', '029-12-O', 
 '030+00', '030+04', '030+08', '030+12', '030+30', '030+60', '030+75', '030+79_MGA', '030-04', '030-08', '030-12', '032+81_MGA', 
 '033+00', '034+00', '034+06', '034+12', '034-06', '034-12', '037+79_MGA', '037+85_MGA', '038+00', '038+04', '038+48_MGA', '038-04',
 '039+45_MGA', '039+46_MGA', '040+36_MGA', '040+43_MGA', '040+45', '040+60', '040+88_MGA', '041+47_MGA', '041+48_MGA', '041+50_MGA',
 '041+53_MGA', '041+78_btx', '041+81_MGA', '041-52-O', '042+41_MGA', '042+43_MGA', '042+45_MGA', '042+87_MGA', '042-56-O', 
 '043+44_MGA', '043+46_MGA', '043+49_btx', '043-49-O', '044+42_MGA', '044+47_MGA', '044+49_MGA', '044+51_MGA', '044+54_MGA', 
 '044+59_MGA', '045+00', '045+06', '045+12', '045+30', '045+42_MGA', '045+56_MGA', '045+89_MGA', '045-06', '045-12', '045-54-O', 
 '046+34_MGA', '046+45_MGA', '046+47_MGA', '046+48', '046-47-O', '046-58-O', '047+50_MGA', '047+52_MGA', '047-25_MGA', '047-51-O', 
 '048+44_MGA', '048+55_MGA', '048+57_MGA', '048+88_MGA', '048-27_MGA', '048-48-O', '049+00', '049+06', '049+12', '049+46_MGA', 
 '049+47_MGA', '049+60_MGA', '049+62', '049+88_MGA', '049-06', '049-12', '049-52-O', '049-55-O', '050+31_MGA', '050+48_MGA', 
 '050+60', '050+63_MGA', '050-29_MGA', '051+60_btx', '051-50-O', '052+44_MGA', '052+87_MGA', '052-33_MGA', '053+00', '053+04', 
 '053+33_MGA', '053+46_MGA', '053+58_MGA', '053+88_MGA', '053-04', '054+87_MGA', '054-35_MGA', '055+33_MGA', '055+36_MGA', 
 '055+63_MGA', '055-53-O', '056+88_MGA', '056-50-O', '057+35_MGA', '058+37_MGA', '058+57', '059+36_MGA', '059-24_MGA', '059-48-O', 
 '060+00', '060+04', '060+08', '060+12', '060+30', '060+38_MGA', '060+56', '060+60', '060+75', '060+78_MGA', '060-04', '060-08',
 '060-12', '060-30', '060-45', '060-75', '061-25_MGA', '062+39_MGA', '062+43_MGA', '062+44_MGA', '062+52_MGA', '062+62', 
 '062+88_MGA', '063+41_MGA', '063+43_MGA', '063+44_MGA', '063+47_MGA', '063+55_btx', '064+00', '064+06', '064+12', '064+42_MGA', 
 '064+44_MGA', '064-06', '064-12', '065+00', '065+48_MGA', '065-29_MGA', '066+42_MGA', '066+47_MGA', '067+43_MGA', '067+46_MGA', 
 '068+00', '068+04', '068+51_MGA', '068+55_MGA', '068-04', '069+42_MGA', '069+45_MGA', '069+49_MGA', '069+57_MGA', '069+83_MGA', 
 '070+53_MGA', '070+54', '070+60', '070+69_MGA', '070+80_MGA', '071+43_MGA', '071+48_MGA', '071+60_MGA', '071+62_btx',
 '072+47_MGA', '072+51_MGA', '072+55_MGA', '072+76_MGA', '073+53_MGA', '073+72_MGA', '074+45_MGA', '074+49_MGA', '074+57_MGA', 
 '074+66_MGA', '075+00', '075+12', '075+30', '075+35', '075+44_MGA', '075+83_MGA', '075-06', '075-12', '075-30', '075-35_MGA',
 '075-45', '076+50_MGA', '076+88_MGA', '077+45_MGA', '077+69_MGA', '077+89_MGA', '078+52_MGA', '078+57_MGA', '078+76_MGA',
 '079+00', '079-06', '079-12', '080+45', '080+59_MGA', '080+60', '080+66_MGA', '080-45', '081+34_MGA', '082+35', '082+57_MGA', 
 '083+00', '083+04', '083+73_MGA', '083-04', '084+62_MGA', '085+33_MGA', '085+35_MGA', '085+59_MGA', '086+34_MGA', '086+47_MGA',
 '086+57_MGA', '086+66_MGA', '086+77', '088+34_MGA', '088+36', '088+55_MGA', '088+64_MGA', '089+70', '090+00', '090+04', '090+08', 
 '090+12', '090+30', '090+34_MGA', '090+49_MGA', '090+59_MGA', '090+60', '090+67_MGA', '090+75', '090-04', '090-08', '090-12', 
 '090-30', '090-45', '090-75', '091+56_MGA', '091-59_MGA', '092+65_MGA', '092+72_MGA', '093+36_MGA', '094+00', '094+06', '094+12', 
 '094+58_MGA', '094+61_MGA', '094-06', '094-12', '098+00', '098+04', '098+60_MGA', '098-04', '099+56_btx', 
 
 '100+00', '100+06', 
 '100+12', '100+60', '100-06', '100-12', '100-60', '101+04', '101-04', '101-24_btx', '102+61_MGA', '103+81_MGA', '104+77_btx', 
 '105+00', '105+06', '105+12', '105+30', '105-06', '105-12', '105-30', '105-45', '106+63_MGA', '109+00', '109+04', '109+08', 
 '109+12', '109+68_MGA', '109-04', '109-08', '109-12', '110+60', '110-60', '110-62_MGA', '111+70_MGA', '113+00', '113+04', 
 '113-04', '115+69_MGA', '115+71_MGA', '116+00', '116+04', '116-04', '116-63_MGA', '117+01', '120+00', '120+04', '120+06', 
 '120+08', '120+12', '120+18', '120+30', '120+45', '120+60', '120+67_btx', '120+75', '120-04', '120-06', '120-08', '120-08-RV', 
 '120-12', '120-24_btx', '120-30', '120-45', '120-60', '120-61-O', '120-75', '121+74_MGA', '123-53-O', '124+00', '124+04', '124-04', 
 '125+12', '125-12', '126-24_btx', '126-55-O', '126-59-O', '128+00', '128+04', '128+71_MGA', '128-04', '130+60', '130-60', '131+00', 
 '131+04', '131-04', '133-55-O', '134-51-O', '135+00', '135+06', '135+12', '135+30', '135-03', '135-06', '135-12', '135-30', 
 '135-45', '136+71_MGA', '137+70_MGA', '138+64_MGA', '139+00', '139+04', '139+27_btx', '139+61_MGA', '139-04', '140+06', '140+12',
 '140+24_btx', '140+60', '140-06', '140-12', '140-18_btx', '140-55-O', '140-60', '141+72_MGA', '142+35_btx', '143+00', '143+04', 
 '143+60_MGA', '143+76_MGA', '143-04', '143-47_MGA', '144+70_MGA', '145+62_MGA', '146+00', '146+04', '146+08', '146+12', 
 '146+18_btx', '146+24_btx', '146+26_btx', '146+36_btx', '146-04', '146-08', '146-12', '146-18_btx', '146-46_MGA', '147+60_MGA', 
 '147+64_MGA', '147-46_MGA', '149+59_MGA', '149+62_MGA', '149+72_MGA', '150+00', '150+04', '150+08', '150+16', '150+30',
 '150+60', '150+65_MGA', '150+75', '150-04', '150-08', '150-08-RV', '150-16', '150-30', '150-45', '150-60', '151+60_MGA',
 '151+70_MGA', '151+79_MGA', '151-45_MGA', '152+34_btx', '152+63_MGA', '154+00', '154+04', '154+59_MGA', '154+62_MGA', '154-04', 
 '155+65_MGA', '155-27_btx', '157+28_btx', '157+60_MGA', '158+00', '158+04', '158+12', '158+18', '158+63_MGA', '158-04', '158-12',
 '159+26_btx', '159+39_MGA', '159+58_MGA', '160+06', '160+12', '160+18_btx', '160+24_btx', '160+45', '160+56_MGA', '160+60', 
 '160+61_MGA', '160-06', '160-12', '160-18_btx', '160-24_btx', '160-45', '160-60', '161+00', '161+04', '161+34_MGA', '161-04', 
 '162+34_btx', '162+40_MGA', '162+60_MGA', '162+64_MGA', '163+36_MGA', '163+38_MGA', '163+78_MGA', '164+32_MGA', '164+34_MGA', 
 '165+00', '165+04', '165+08', '165+18', '165+30', '165+33_MGA', '165+38_MGA', '165+61_MGA', '165+62_MGA', '165-04', '165-08',
 '165-30', '165-45', '167+31_MGA', '167+34_MGA', '167+39_MGA', '168+30_MGA', '168+31_MGA', '168+46_MGA', '168+55_MGA', '168+62_MGA',
 '168+63_MGA', '169+00', '169+04', '169+08', '169+12', '169+18_btx', '169+24_btx', '169+33_MGA', '169+35_MGA', '169+53_MGA', 
 '169+61_MGA', '169-04', '169-08', '169-12', '169-18_btx', '169-24_btx', '170+31_MGA', '170+34_btx', '170+60', '170-60',
 '171+29_MGA', '171+48_MGA', '171-52_MGA', '172+27_MGA', '172+32_MGA', '172+54_MGA', '172+58_btx', '172+63_MGA', '172-52_MGA', 
 '173+00', '173+04', '173+12', '173+18', '173+30_MGA', '173+52_MGA', '173-04', '173-12', '173-51_MGA', '174+28_MGA', '174+33_MGA', 
 '174+35_MGA', '174+49_MGA', '174-51_MGA', '175+26_MGA', '175+31_MGA', '175+43_MGA', '175+58_MGA', '175+65_btx', '175-27-O',
 '176+00', '176+04', '176+27_MGA', '176+29_MGA', '176-04', '176-27-O', '176-49_MGA', '177+24_MGA', '177+32', '177+49_MGA',
 '177+51_MGA', '177-49_MGA', '178+24_MGA', '178+26_MGA', '178+28_MGA', '178+30_MGA', '178+36_btx', '178+42_MGA', '178+44_MGA', 
 '178-48_MGA', '179+57_MGA', '179-25-O', '180+00', '180+04', '180+08', '180+12', '180+18', '180+19', '180+29_MGA', '180+30', 
 '180+31_MGA', '180+33_MGA', '180+60', '180+75', '180-04', '180-08', '180-08-RV', '180-12', '180-30', '180-45', '180-60', '180-75',
 '181+25_MGA', '181+27_MGA', '181+32_btx', '181+42_MGA', '181-46_MGA', '182+25', '182+29_MGA', '182+30_MGA', '182-45_MGA', 
 '183-44_MGA', '184+00', '184+04', '184+30_MGA', '184+31', '184-04', '184-43_MGA', '185+27_MGA', '185+57_MGA', '185-42_MGA', 
 '186+30', '186+31_btx', '186+42', '186+48', '187+24_MGA', '187+26_MGA', '187+28_MGA', '187+48_MGA', '187-40_MGA', '187-41_MGA',
 '188+00', '188+04', '188+12', '188+18', '188+58_MGA', '188-04', '188-12', '189+25_MGA', '189+27_MGA', '189+29', '189+47_MGA', 
 '190+44_MGA', '190+45_MGA', '190+60', '190-50_MGA', '190-60', '191+00', '191+04', '191+08', '191+12', '191+18_btx', '191+22_MGA',
 '191+24_MGA', '191+26_MGA', '191+28_MGA', '191+44_MGA', '191+52_MGA', '191-04', '191-08', '191-12', '191-18_btx', '191-24_btx',
 '192-47_MGA', '192-48_MGA', '193+23_MGA', '193+25_MGA', '193+27_MGA', '193+29_MGA', '194+24_MGA', '194+26_MGA', '194+51_MGA', 
 '194-44_MGA', '195+00', '195+04', '195+08', '195+18', '195+28_MGA', '195+30', '195+30_MGA', '195+32_MGA', '195-04', '195-08',
 '195-30', '195-42_MGA', '196+25_MGA', '196+27_MGA', '196+37_MGA', '197+29_MGA', '197+31_MGA', '197-39_MGA', '198+08', '198+21_MGA',
 '198+24_MGA', '198+26_MGA', '198+33_MGA', '198+36_MGA', '198+38_MGA', '198+41_MGA', '199+00', '199+04', '199+28', '199+30_MGA',
 '199+43_MGA', '199-04', 
 
 '200+22_MGA', '200+25_MGA', '200+32_MGA', '200+34_MGA', '200+45', '200+60', '200-45', '200-60',
 '201+26_btx', '201+27_MGA', '201+29', '201+30_btx', '201+37_MGA', '202+21_MGA', '202+23_MGA', '202+31_MGA', '202+33_MGA', 
 '203+00', '203+04', '203+12', '203+18', '203+21', '203+26_MGA', '203+28_MGA', '203+30_MGA', '203-04', '203-12', '204+22',
 '204+24_MGA', '206+00', '206+04', '206+21', '206+29_MGA', '206+38_MGA', '206-04', '207+27_btx', '209+73_btx', '210+00', '210+04', 
 '210+08', '210+16', '210+30', '210+60', '210+75', '210-04', '210-08', '210-16', '212+38_MGA', '214+00', '214+04', '214+08', 
 '214+12', '214+18_btx', '214+24_btx', '214-04', '214-08', '214-12', '216+53_btx', '217+49_MGA', '218+00', '218+04', '218-04',
 '219+65_MGA', '219+68_MGA', '220+60', '221+04', '221+84', '221-04', '222+70_MGA', '222+71_MGA', '223+26_MGA', '223+27_MGA',
 '223+55', '225+00', '225+04', '225+30', '225-04', '225-12', '226+31_MGA', '228+60', '228-49', '229+04', '229-04', '230+32_MGA',
 '230+60', '232+30_btx', '232+38_MGA', '234+44_MGA', '235+00', '235+06', '235+12', '235-06', '235-12', '237+44_MGA', '237+48_MGA',
 '240+00', '240+04', '240+12', '240+18', '240+30', '240+45', '240+60', '240+75', '240-04', '240-12', '241+52_MGA', '246+77_btx',
 '250+60', '251+00', '253+51', '253+75', '255+00', '259+00', '259+57-O', '260+40', '260+55', '260+60', '261+48', '263-03', '264+20', 
 '266+44', '266+56-O', '266-06', '269-37-O_TESS', '270+00', '270+12', '270+60', '270+75', '270-12', '271-19-O_TESS', '272+58',
 '272-40-O_TESS', '273-20-O_TESS', '273-41-O_TESS', '277+76', '277-18-O_TESS', '277-20-O_TESS', '277-35-O', '278+00', '278-09',
 '278-21-O_TESS', '278-41-O_TESS', '279+66', '279-19-O_TESS', '279-31-O', '279-34-O', '279-40-O_TESS', '280+45', '280+49', 
 '280+60', '280-20-O_TESS', '280-27', '280-33-O', '281+00', '281+06', '281+12', '281-06', '281-35-O', '282-21-O_TESS', '282-34-O', 
 '283-01-C', '283-19-O_TESS', '284-20-O_TESS', '284-24-O_TESS', '284-26-O_TESS', '284-28-O_TESS', '284-30-O_TESS', '284-39',
 '284-40-O_TESS', '285+00', '285-22-O_TESS', '285-33-O_TESS', '286+44', '286-29-O_TESS', '287-23-O_TESS', '288-26-O_TESS',
 '288-28-O_TESS', '288-29-O_TESS', '288-31-O_TESS', '289-33-O_TESS', '290+60', '290-01-C', '290-30-O_TESS', '291-00-C', '292-26', 
 '296+00', '296+06', '296+12', '296-06', '296-12', '298-25', 
 
 '300+00', '300+04', '300+12', '300+60', '300+75', '300+75-S', 
 '300-04', '300-12', '300-23', '305-00-C', '30Dor', '310+60', '311+00', '311+06', '311+12', '311-06', '311-12', '315-02-O',
 '317+12', '320+45', '320+60', '325+76', '326+00', '326+06', '326+12', '326-06', '326-12', '330+12', '330+60', '330+75', '330-12', 
 '335+06', '335+12', '335+61_btx', '335-12', '340+00', '340+06', '340+10', '340+12', '340+14', '340+60', '340-06', '340-10', 
 '340-12', '340-14', '345+00', '345+02', '345+14', '345-02', '345-12', '347+00', '347+20-O', '348+17-O', '349+22-O', '350+00', 
 '350+04', '350+12', '350+18-O', '350+19-O', '350+20-O', '350+23-O', '350+60', '350-04', '350-12', '351+17-O', '351+18-O', 
 '351+21-O', '351+24-O', '351-02-O', '352+22-O', '353+17-O', '353+24-O', '354+19-O', '354-03-O', '355+00', '355+02', '355+04',
 '355+08', '355+22-O', '355+23-O', '355-02', '355-08', '356+00-C', '356+12-O', '356-03-O', '356-04-O', '356-06-O', '357+02-C', 
 '357+02-O', '357+03-O', '357+05', '357-03-O', '357-04-O', '358+00', '358+00-C', '358+02-O', '358+04', '358+06', '358-03-O',
 '358-04', '358-05-O', '359+01', '359+01-O', '359+03-O', '359+04-O', '359-02-O', '359-17-C', '47TUC', '71-56-O', 
 
 'ALPHAPER','ANDR1', 'ANDR2', 'ANDR3', 
 
 'BAADEWIN_001-04', 'BOOTES1', 'BRAVAFREE_000-05', 'Bestars', 
 
 'CARINA',
 'COROT1', 'COROT2', 'COROTA', 'COROTA2', 'COROTA2-RV', 'COROTA3', 'COROTC', 
 
 'CVZ_FILL01_btx', 'CVZ_FILL02_btx', 'CVZ_FILL03_btx', 'CVZ_OB01_btx', 'CVZ_OB02_btx',
 'CVZ_OB03_btx', 'CVZ_OB04_btx', 'CVZ_OB05_btx', 'CVZ_OB06_btx', 'CVZ_OB07_btx', 'CVZ_OB08_btx', 'CVZ_OB09_btx', 'CVZ_OB10_btx',
 'CVZ_OB11_btx', 'CVZ_OB12_btx', 'CVZ_OB13_btx', 'CVZ_OB14_btx', 'CVZ_OB15_btx', 'CVZ_OB16_btx', 'CVZ_OB17_btx', 'CVZ_OB18_btx', 
 'CVZ_OB19_btx', 'CVZ_OB20_btx', 'CVZ_OB21_btx', 
 
 'DRACO', 
 
 'GALCEN', 'GD1-1', 'GD1-2', 'GD1-3', 'GD1-4', 'GD1-5', 
 
 'HD46375',
 
 'IC342_MGA', 'IC348', 'IC348_RV', 
 
 'K01_082+17', 'K02_080+18', 'K03_077+20', 'K04_083+13', 'K05_080+14', 'K06_078+16',
 'K07_075+17', 'K08_073+19', 'K09_081+11', 'K10_079+12', 'K11_076+13', 'K12_074+15', 'K13_071+16', 'K14_080+08', 'K15_077+10',
 'K16_075+11', 'K17_072+13', 'K18_070+14', 'K19_076+07', 'K20_073+09', 'K21_071+10', 'K2_C2_352+12_btx', 'K2_C4_168-21',
 'K2_C4_172-20', 'K2_C4_177-21', 'K2_C7_009-18', 'K2_C7_010-10', 

'LAMBDAORI-A', 'LAMBDAORI-B', 'LAMBDAORI-C', 

'LMC1', 'LMC10',
 'LMC11', 'LMC12', 'LMC13', 'LMC14', 'LMC16', 'LMC17', 'LMC2', 'LMC3', 'LMC4', 'LMC5', 'LMC6', 'LMC7', 'LMC8', 'LMC9', 
 
 'M10', 'M107', 'M12-N', 'M12-S', 'M13', 'M15', 'M2', 'M3', 'M3-RV', 'M33', 'M35N2158', 'M4', 'M5', 'M53', 'M54SGRC-2', 'M54SGRC1',
 'M55', 'M5PAL5', 'M67', 'M67-RV', 'M68', 'M71', 'M79', 'M92', 
 
 'Mdwarfs', 
 
 'N1333', 'N1851', 'N188', 'N188-RV', 'N2204', 'N2243',
 'N2243-S', 'N2264', 'N2420', 'N2808', 'N288', 'N3201', 'N3201RRL', 'N362', 'N4147', 'N5466', 'N5634SGR2', 'N6229', 'N6388',
 'N6397', 'N6441', 'N6752', 'N6791', 'N6819', 'N7789', 'NGP', 
 
 'ORIONA', 'ORIONA-B', 'ORIONA-C', 'ORIONA-D', 'ORIONA-E', 'ORIONB',
 'ORIONB-A', 'ORIONB-B', 'ORIONC', 'ORIOND', 'ORIONE', 'ORIONOB1AB-A', 'ORIONOB1AB-B', 'ORIONOB1AB-C', 'ORIONOB1AB-D',
 'ORIONOB1AB-E', 'ORIONOB1AB-F', 
 
 'ORPHAN-1', 'ORPHAN-2', 'ORPHAN-3', 'ORPHAN-4', 'ORPHAN-5', 
 
 'Omegacen', 
 
 'PAL1', 'PAL5-1', 'PAL5-2',
 
 'PLEIADES-E', 'PLEIADES-W', 'Pleiades', 
 
 'RCB', 
 
 'SA57-E', 'SA57-N', 'SA57-S', 'SA57-W', 
 
 'SCULPTOR', 'SEXTANS', 
 
 'SGR1', 'SGRC-1',
 'SGRC-3', 'SGRC-4', 'SGRC3', 'SGRCMA-04', 'SGRCMI+02', 'SGRCNW+02', 'SGRT-1', 'SGRT-2', 'SMC1', 'SMC2', 'SMC3', 'SMC4', 'SMC5',
 'SMC6', 'SMC7', 'SgrO2', 'SgrO3', 'Sgr_faint', 
 
 'TAUL1495', 'TAUL1521', 'TAUL1527', 'TAUL1536', 'TRIAND-1', 'TRIAND-2', 'TRIAND-3',
 'TRIAND-4', 'TRIAND-5', 
 
 'URMINOR', 
 
 'VOD1', 'VOD2', 'VOD3', 
 
 'W3-4', 'W5', 'W5a', 
 
 'calibration', 
 
 'cepheid', 
 
 'hip', 'misc', 
 
 'moving_groups', 
 
 'rrlyr', 'rv'

"""

# %%
# Group unique star fields in targets of various size 

Globular_Clusters = [
'47TUC',     # 372 Stars   Age: 13.06 Gyr    FeH: -0.78
'M4',        # 334 Stars
'M5PAL5',    # 718 Stars   Age: 10.62 Gyr    FeH: -1.12
'M10',       # 475 Stars
'M12-N',     # 308 Stars   Age: 12.67 Gyr    FeH: -1.14
'M12-S',     # 462 Stars
'M15',       # 1189 Stars  Age: 12.00 Gyr    FeH: -2.37
'M68',       # 362 Stars
'M71',       # 1028 Stars  Age: 9-10  Gyr    FeH: -0.78
'M79' ,      # 373 Stars
'N288',      # 375 Stars   Age: 10.62 Gyr    FeH: -1.14
'N362',      # 270 Stars   Age: 10.37 Gyr    FeH: -1.09
'N1851',     # 382 Stars   Age: 9.2   Gyr    FeH: -1.27
'N2808' ,    # 365 Stars
'N3201',     # 355 Stars
'N6441',     # 208 Stars   Age: 13-13.7 Gyr  FeH: -0.53
'Omegacen',  # 1201 Stars  Age: 11.52 Gyr    FeH: -1.35
]

Globular_Clusters1 = [
'47TUC',     # 372 Stars   Age: 13.06 Gyr    FeH: -0.78
]

Globular_Clusters2 = [
'M4',        # 334 Stars
'M5PAL5',    # 718 Stars   Age: 10.62 Gyr    FeH: -1.12
]

Globular_Clusters3 = [
'M10',       # 475 Stars
'M12-N',     # 308 Stars   Age: 12.67 Gyr    FeH: -1.14
'M12-S',     # 462 Stars
]

Globular_Clusters4 = [
'M15',       # 1189 Stars  Age: 12.00 Gyr    FeH: -2.37
'M68',       # 362 Stars
'M71',       # 1028 Stars  Age: 9-10  Gyr    FeH: -0.78
'M79' ,      # 373 Stars
]

Globular_Clusters5 = [
'N288',      # 375 Stars   Age: 10.62 Gyr    FeH: -1.14
'N362',      # 270 Stars   Age: 10.37 Gyr    FeH: -1.09
'N1851',     # 382 Stars   Age: 9.2   Gyr    FeH: -1.27
'N2808' ,    # 365 Stars
'N3201',     # 355 Stars
]

Globular_Clusters6 = [
'N6441',     # 208 Stars   Age: 13-13.7 Gyr  FeH: -0.53
'Omegacen',  # 1201 Stars  Age: 11.52 Gyr    FeH: -1.35
]

Six_Metal_Rich_Clusters =[
'N2420',
'M67',      # 894 Stars
'N188',     # 578 Stars
'N6791',
'N6819',
'N7789', 
]

Four_Metal_Poor_Clusters = [
'M53',
'M92',
'N5466',
'M2',
]


Open_Clusters = [
'M67',      # 894 Stars
'N188',     # 578 Stars
'N2204',    # 254 Stars
'N2243-S',  # 324 Stars
'198+08',   # 424 Stars               # Berkeley 29
'206+04',   # 265 Stars               # Berleley_31
'225-04',   # 265 Stars               # Berleley_33
'045+00',   # 264 Stars               # Berleley_43
'053+04',   # 263 Stars               # Berleley_44
]

APOGEE_1_Open_Clusters = [
'198+08',   # 424 Stars               # Berkeley 29
'Pleiades',
'N188',     # 578 Stars
'M35N2158',
'N2243',
'N2243-S',
'N2420',
'M67',      # 894 Stars
'N6791',
'N6819', 
'N7789', 
]

APOGEE_2N_Open_Clusters = [
'N188',     # 578 Stars
'N2243',
'N2204',
]

APOGEE_2S_Open_Clusters = [
'N2243-S',
'M67', 
]

Young_Clusters = [
'ALPHAPER',     # 206 Stars
'LAMBDAORI-A',  # 606 Stars
'LAMBDAORI-B',  # 425 Stars
'LAMBDAORI-C',  # 591 Stars
'N2264',        # 170 Stars
'ORIONA-B',     # 194 Stars
'ORIONA-C',     # 160 Stars
'ORIONA-D',     # 156 Stars
'ORIONA-E',     # 170 Stars
'ORIONB-A',     # 539 Stars
'ORIONB-B',     # 495 Stars
'ORIONOB1AB-A', # 322 Stars
'ORIONOB1AB-B', # 518 Stars
'ORIONOB1AB-C', # 537 Stars
'ORIONOB1AB-D', # 339 Stars
'ORIONOB1AB-E', # 543 Stars
'ORIONOB1AB-F', # 436 Stars
'PLEIADES-E',   # 226 Stars
'PLEIADES-W',   # 243 Stars
'TAUL1495',     # 233 Stars
'TAUL1521',     # 243 Stars
'TAUL1527',     # 235 Stars
'TAUL1536',     # 221 Stars
]

ALPHAPER_Young_Clusters = [
'ALPHAPER',     # 206 Stars
]

ANDR = [
'ANDR1', 'ANDR2', 'ANDR3',
]

CARINA = [
'CARINA',
]

COROT = [
'COROT1', 'COROT2', 'COROTA', 'COROTA2', 'COROTA2-RV', 'COROTA3', 'COROTC', 
]

CVZ1 = [
'CVZ_FILL01_btx', 'CVZ_FILL02_btx', 'CVZ_FILL03_btx', 'CVZ_OB01_btx', 
]

CVZ2 = [
'CVZ_OB02_btx','CVZ_OB03_btx', 'CVZ_OB04_btx', 'CVZ_OB05_btx', 
]

CVZ3 = [
'CVZ_OB06_btx', 'CVZ_OB07_btx', 'CVZ_OB08_btx', 'CVZ_OB09_btx', 
]

CVZ4 = [
'CVZ_OB10_btx','CVZ_OB11_btx', 'CVZ_OB12_btx', 'CVZ_OB13_btx', 
]

CVZ5 = [
'CVZ_OB14_btx', 'CVZ_OB15_btx', 'CVZ_OB16_btx', 'CVZ_OB17_btx', 
]

CVZ6 = [
'CVZ_OB18_btx', 'CVZ_OB19_btx', 'CVZ_OB20_btx', 'CVZ_OB21_btx', 
]

LAMBDAORI_Young_Clusters = [
'LAMBDAORI-A',  # 606 Stars
'LAMBDAORI-B',  # 425 Stars
'LAMBDAORI-C',  # 591 Stars
]

ORION_Young_Clusters = [
'ORIONA-B',     # 194 Stars
'ORIONA-C',     # 160 Stars
'ORIONA-D',     # 156 Stars
'ORIONA-E',     # 170 Stars
'ORIONB-A',     # 539 Stars
'ORIONB-B',     # 495 Stars
'ORIONOB1AB-A', # 322 Stars
'ORIONOB1AB-B', # 518 Stars
'ORIONOB1AB-C', # 537 Stars
'ORIONOB1AB-D', # 339 Stars
'ORIONOB1AB-E', # 543 Stars
'ORIONOB1AB-F', # 436 Stars
]

PLEIADES_Young_Clusters = [
'PLEIADES-E',   # 226 Stars
'PLEIADES-W',   # 243 Stars
'Pleiades',
]

TAUL_Young_Clusters = [
'TAUL1495',     # 233 Stars
'TAUL1521',     # 243 Stars
'TAUL1527',     # 235 Stars
'TAUL1536',     # 221 Stars
]

Halo_btx =  [
'011+47_btx',   # 253 Stars
'041+78_btx',   # 251 Stars
'043+49_btx',   # 239 Stars
'051+60_btx',   # 258 Stars
'063+55_btx',   # 242 Stars
'071+62_btx',   # 253 Stars
'099+56_btx',   # 229 Stars
'104+77_btx',   # 239 Stars
'120+67_btx',   # 247 Stars
'172+58_btx',   # 238 Stars
'175+65_btx',   # 255 Stars
'209+73_btx',   # 230 Stars
'216+53_btx',   # 252 Stars
'246+77_btx',   # 243 Stars
'335+61_btx',   # 261 Stars
]

Halo_Stream = [
'GD1-1',        # 491 Stars
'GD1-2',        # 948 Stars
'GD1-3',        # 534 Stars
'GD1-4',        # 420 Stars
'GD1-5',        # 281 Stars
'ORPHAN-1',     # 328 Stars
'ORPHAN-2',     # 355 Stars
'ORPHAN-3',     # 397 Stars
'ORPHAN-4',     # 391 Stars
'ORPHAN-5',     # 452 Stars
'PAL5-1',       # 416 Stars
'PAL5-2',       # 530 Stars
'SGRT-1',       # 212 Stars
'TRIAND-1',     # 254 Stars
'TRIAND-2',     # 239 Stars
'TRIAND-3',     # 250 Stars
'TRIAND-4',     # 235 Stars
'TRIAND-5',     # 242 Stars
]

GD1_Halo_Stream = [
'GD1-1',        # 491 Stars
'GD1-2',        # 948 Stars
'GD1-3',        # 534 Stars
'GD1-4',        # 420 Stars
'GD1-5',        # 281 Stars
]

ORPHAN_Halo_Stream = [
'ORPHAN-1',     # 328 Stars
'ORPHAN-2',     # 355 Stars
'ORPHAN-3',     # 397 Stars
'ORPHAN-4',     # 391 Stars
'ORPHAN-5',     # 452 Stars
]

PAL5_Halo_Stream = [
'PAL5-1',       # 416 Stars
'PAL5-2',       # 530 Stars
]

SGRT_Halo_Stream = [
'SGRT-1',       # 212 Stars
]

TRIAND_Halo_Stream = [

'TRIAND-1',     # 254 Stars
'TRIAND-2',     # 239 Stars
'TRIAND-3',     # 250 Stars
'TRIAND-4',     # 235 Stars
'TRIAND-5',     # 242 Stars
]

Kepler_01_09 = [
'K01_082+17',   # 742
'K02_080+18',   # 726
'K03_077+20',   # 744
'K04_083+13',   # 1207
'K05_080+14',   # 961
'K06_078+16',   # 1234
'K07_075+17',   # 979
'K08_073+19',   # 858
'K09_081+11',   # 1450
]

Kepler_10_019 = [
'K10_079+12',   # 1404
'K11_076+13',   # 962
'K12_074+15',   # 972
'K13_071+16',   # 743
'K14_080+08',   # 1160
'K15_077+10',   # 1311
'K16_075+11',   # 1440
'K17_072+13',   # 1147
'K18_070+14',   # 1124
'K19_076+07',   # 1367
]

Kepler_20_021 = [
'K20_073+09',   # 1199
'K21_071+10',   # 1584
]


k2_notes = """ 
APOGEE-2 is targeting several thousand giant stars in select K2 Mission Campaign fields, 
largely from the K2 Galactic Archaeology Program’s (GAP) sample of asteroseismic targets. 
The details of the GAP sample are given in J. Zinn et al. (in prep.). 
Several considerations were made in the final target selection:
1. stars known to host planets
2. confirmed oscillators in the K2 GAP sample
3. red giants targeted by GAP, but not observed by GALAH
4. red giants targeted by GAP, but observed by GALAH
5. unbiased M dwarf sample
Any remaining fibers followed the criteria for the main red star sample. 
The stars from this science program have targeting bit 6 set in APOGEE2_TARGET3. 
All APOGEE-2 designs belonging to K2 fields have PROGRAMNAME tag value “k2” or "k2_btx". """

K2 = [
'K2_C2_352+12_btx',   # 260
'K2_C4_168-21',       # 439
'K2_C4_172-20',       # 455
'K2_C4_177-21',       # 405
'K2_C7_009-18',       # 594
'K2_C7_010-10',       # 397
]

LMC = [
'LMC1', 'LMC2', 'LMC3', 'LMC4', 'LMC5', 'LMC6', 'LMC7', 'LMC8', 'LMC9', 
'LMC10', 'LMC11', 'LMC12', 'LMC13', 'LMC14', 'LMC16', 'LMC17',
]

Messier = [
 'M2', 'M3', 'M3-RV', 'M4', 'M5', 'M5PAL5',
 'M10', 'M12-N', 'M12-S', 'M13', 'M15',  'M33', 'M35N2158',  'M53', 'M54SGRC-2', 'M54SGRC1',
 'M55',  'M67', 'M67-RV', 'M68', 'M71', 'M79', 'M92', 'M107', 
]

NGC = [
 'N188', 'N188-RV', 'N288', 'N362','N1333', 'N1851',  
 'N2204', 'N2243', 'N2243-S', 'N2264', 'N2420', 'N2808',  
 'N3201', 'N3201RRL', 'N4147', 'N5466', 'N5634SGR2', 
 'N6229', 'N6388','N6397', 'N6441', 'N6752', 'N6791', 'N6819', 'N7789', 
]

NGC1 = [
'N188', 'N188-RV', 'N288', 'N362','N1333', 'N1851',
]

NGC2 = [
'N2204', 'N2243', 'N2243-S', 'N2264', 'N2420', 'N2808',
]

NGC3 = [
'N3201', 'N3201RRL', 'N4147', 'N5466', 'N5634SGR2', 
]

NGC4 = [
'N6229', 'N6388','N6397', 'N6441', 'N6752', 'N6791', 'N6819', 'N7789',
]



SMC = [
 'SMC1', 'SMC2', 'SMC3', 'SMC4', 'SMC5', 'SMC6', 'SMC7', 
]


#

# %%
#
#
#  Select a Star Cluster sample field by comment/uncomment target
#
#

fields = Globular_Clusters
#fields = Globular_Clusters1
#fields = Globular_Clusters2
#fields = Globular_Clusters3
#fields = Globular_Clusters4
#fields = Globular_Clusters5
#fields = Globular_Clusters6

#fields = APOGEE_1_Open_Clusters
#fields = APOGEE_2N_Open_Clusters
#fields = APOGEE_2S_Open_Clusters

#fields = Open_Clusters 

#fields = Young_Clusters
#fields = ALPHAPER_Young_Clusters

#fields = ANDR
#fields = CARINA
#fields = COROT

#fields = CVZ1
#fields = CVZ2
#fields = CVZ3
#fields = CVZ4
#fields = CVZ5
#fields = CVZ6

#fields = LAMBDAORI_Young_Clusters
#fields = ORION_Young_Clusters
#fields = PLEIADES_Young_Clusters
#fields = TAUL_Young_Clusters 

#fields = Halo_btx

#fields = Halo_Stream
#fields = GD1_Halo_Stream
#fields = ORPHAN_Halo_Stream
#fields = PAL5_Halo_Stream
#fields = SGRT_Halo_Stream
#fields = TRIAND_Halo_Stream

#fields = Kepler_01_09
#fields = Kepler_10_019
#fields = Kepler_20_021
#fields = K2

#fields = LMC

#fields = Messier

#fields = NGC
#fields = NGC1
#fields = NGC2
#fields = NGC3
#fields = NGC4

#fields = SMC

#fields = Six_Metal_Rich_Clusters
#fields = Four_Metal_Poor_Clusters

print("\nSubset of Fields: " + str(len(fields)))
print(fields)
print("\n")

# %%
# Choose which plots to show

Display_Plot_Indicator = "N"

Plot_001_flag = "Y"  #<<<< HR_Diagram Mapping BP_RP to Absolute Magnitude
Plot_002_flag = "N"      # HR_Diagram_Mapping BP_RP to Absolute Magnitude by Star Class

Plot_003_flag = "N"      # HR Diagram Mapping BP-RP to Absolute Magnitude by LogG
Plot_004_flag = "N"      # HR Diagram Mapping BP-RP to GAIA_PHOT_G_MEAN_MAG by Star Class

Plot_005_flag = "Y"  #<<<< HR_Diagram_Mapping Teff  to LogG by Star Class
Plot_006_flag = "N"      # HR_Diagram_Mapping Teff  to LogG by Total Metal Content [M/H]

Plot_007_flag  = "N"     # HR Diagram Alpha Element Abundance [ALPHA_M]
Plot_007A_flag = "Y" #<<<< HR Diagram [Fe/H]
Plot_007B_flag = "Y" #<<<< HR Diagram Carbon Abundance [C/M]
Plot_007C_flag = "Y" #<<<< HR Diagram Nitrogen Abundance [N/M]

Plot_007D_flag = "N"     # HR Diagram Microturbulent Velocity [VMICRO]
Plot_007E_flag = "N"     # HR Diagram vsini_vmacro [vsini_vmacro]
Plot_007F_flag = "Y" #<<<< HR Diagram Average Radial Velocity [VHELIO_AVG]
Plot_007G_flag = "Y" #<<<< HR Diagram Kilo-Parsecs [KPC]

Plot_008_flag = "N"      # HR Diagram SFD Reddening [SFD_EBV]
Plot_009_flag = "N"      # HR Diagram Gaia Color [BP_RP]

Plot_010_flag = "N"      # Average Radial Velocity [VHELIO_AVG] By RA/Dec
Plot_011_flag = "N"      # GAIA_RADIAL_VELOCITY By RA/Dec

Plot_012_flag = "N"      # LogG By RA/Dec
Plot_013_flag = "N"      # LogG Heatmap APOGEE_ID by Star Class

Plot_014_flag = "N"      # FeH By RA/Dec
Plot_015_flag = "N"      # FeH Heatmap APOGEE_ID by Star Class

Plot_020_flag  = "N"     # Relative Abundance Diagram [AL_FE]-[N_FE]
Plot_020B_flag = "N"     # Relative Abundance Diagram [AL_FE]-[N_FE] Bar Fe/H

Plot_021_flag  = "N"     # Relative Abundance Diagram [C_FE]-[N_FE]
Plot_021B_flag = "N"     # Relative Abundance Diagram [C_FE]-[N_FE] Bar Fe/H

Plot_022_flag  = "N"     # Relative Abundance Diagram [O_FE]-[N_FE]
Plot_022B_flag = "N"     # Relative Abundance Diagram [O_FE]-[N_FE] Bar Fe/H


Plot_030_flag = "N"      # Plot ['AL_FE']
Plot_031_flag = "N"      # Plot ['C_FE']
Plot_032_flag = "N"      # Plot ['CA_FE']
Plot_033_flag = "N"      # Plot ['CI_FE']
Plot_034_flag = "N"      # Plot ['CI_FE']
Plot_035_flag = "N"      # Plot ['CR_FE']
Plot_036_flag = "N"      # Plot ['CU_FE']
Plot_037_flag = "N"      # Plot ['GE_FE']
Plot_038_flag = "N"      # Plot ['K_FE']
Plot_039_flag = "N"      # Plot ['MG_FE']
Plot_040_flag = "N"      # Plot ['MN_FE']
Plot_041_flag = "N"      # Plot ['NA_FE']
Plot_042_flag = "N"      # Plot ['ND_FE']
Plot_043_flag = "N"      # Plot ['NI_FE']
Plot_044_flag = "N"      # Plot ['N_FE']
Plot_045_flag = "N"      # Plot ['O_FE']
Plot_046_flag = "N"      # Plot ['P_FE']
Plot_047_flag = "N"      # Plot ['RB_FE']
Plot_048_flag = "N"      # Plot ['S_FE']
Plot_049_flag = "N"      # Plot ['TI_FE']
Plot_050_flag = "N"      # Plot ['TIII_FE']
Plot_051_flag = "N"      # Plot ['V_FE']
Plot_052_flag = "N"      # Plot ['YB_FE']

print("\n Flags Set")

# %%
#

# %%
# Main secion
# Select which target sample field from above above
# Select which plots to show from above

# Then execute this cell

for field in fields:

    f1 = df_Apogee[df_Apogee['FIELD'] == field]

    fa = np.array(f1.PARAM)

    param_teff = []
    param_logg = []
    param_vmicro = []
    param_a_h = []
    param_c_m = []
    param_n_m = []
    param_a_m = []
    param_vsini_vmacro = []
    for i in range(len(fa)):
        fa1 = fa[i].replace("(", "")
        fa2 = fa1.replace(")", "")
        fb = fa2.split(',')
        param_teff.append(float(fb[0]))
        param_logg.append(float(fb[1]))
        param_vmicro.append(float(fb[2]))
        param_a_h.append(float(fb[3]))
        param_c_m.append(float(fb[4]))
        param_n_m.append(float(fb[5]))
        param_a_m.append(float(fb[6]))
        param_vsini_vmacro.append(float(fb[7]))

    f1['param_teff'] = param_teff
    f1['param_logg'] = param_logg
    f1['param_vmicro'] = param_vmicro
    f1['param_a_h'] = param_a_h
    f1['param_c_m'] = param_c_m
    f1['param_n_m'] = param_n_m
    f1['param_a_m'] = param_a_m
    f1['param_vsini_vmacro'] = param_vsini_vmacro
            
    print('ProgramName: ' + str(sp.unique(f1['PROGRAMNAME'])))

    print("Field: " + str(field))
    
    fdwarf = f1[f1['LOGG'].astype(float) > 3.7]
    fmain_sequence = f1[f1['LOGG'].astype(float) > 4.20]
    fturnoff       = f1[(f1['LOGG'].astype(float) < 4.20) & (f1['LOGG'].astype(float) > 3.90)]
    fsubgiants     = f1[(f1['LOGG'].astype(float) < 3.90) & (f1['LOGG'].astype(float) > 3.60)]
    fred_clump     = f1[(f1['LOGG'].astype(float) < 2.55) & (f1['LOGG'].astype(float) > 2.35)]
    fred_giants    = f1[f1['LOGG'].astype(float) < 3.60]

    print("\nmain_sequence: " + str(fmain_sequence.shape[0]))
    print("turnoff: " + str(fturnoff.shape[0]))
    print("subgiants: " + str(fsubgiants.shape[0]))
    print("red_giants: " + str(fred_giants.shape[0]))
    print("red_clump: " + str(fred_clump.shape[0]))
    print("red_giants - red_clump: " + str(fred_giants.shape[0] - fred_clump.shape[0]))
    print("dwarfs: " + str(fdwarf.shape[0]))
    
    BA1f = f1[f1['ASPCAP_CLASS'].isin(['BA'])]
    Fd1f = f1[f1['ASPCAP_CLASS'].isin(['Fd_a', 'Fd_b', 'Fd_c', 'Fd_d'])]
    GKd1f = f1[f1['ASPCAP_CLASS'].isin(['GKd_a', 'GKd_b', 'GKd_c', 'GKd_d'])]
    GKg1f = f1[f1['ASPCAP_CLASS'].isin(['GKg_a', 'GKg_b', 'GKg_c', 'GKg_d'])]
    Md1f = f1[f1['ASPCAP_CLASS'].isin(['Md_a', 'Md_b', 'Md_c', 'Md_d'])]
    Mg1f = f1[f1['ASPCAP_CLASS'].isin(['Mg_a', 'Mg_b', 'Mg_c', 'Mg_d'])]
    
    print("\nBA: " + str(BA1f.shape[0]))
    print("Fd: " + str(Fd1f.shape[0]))
    print("GKd: " + str(GKd1f.shape[0]))
    print("GKg: " + str(GKg1f.shape[0]))
    print("Md: " + str(Md1f.shape[0]))
    print("Mg: " + str(Mg1f.shape[0]))
    

    if Plot_001_flag == "Y":
        Plot001(f1)

    if Plot_002_flag == "Y":
        Plot002(f1)
    
    if Plot_003_flag == "Y":
        Plot003(f1)
    
    if Plot_004_flag == "Y":
        Plot004(f1)

    if Plot_005_flag == "Y":
        Plot005(f1)

    if Plot_006_flag == "Y":
        Plot006(f1)

    
    
    
    if Plot_007A_flag == "Y":
        Plot007A(f1)

    if Plot_007_flag == "Y":
        Plot007(f1)

    if Plot_007B_flag == "Y":
        Plot007B(f1)

    if Plot_007C_flag == "Y":
        Plot007C(f1)

    if Plot_007D_flag == "Y":
        Plot007D(f1)

    if Plot_007E_flag == "Y":
        Plot007E(f1)

    if Plot_007F_flag == "Y":
        Plot007F(f1)

    if Plot_007G_flag == "Y":
        Plot007G(f1)

        

    if Plot_008_flag == "Y":
        Plot008(f1)

    if Plot_009_flag == "Y":
        Plot009(f1)

    if Plot_010_flag == "Y":
        Plot010(f1)
        
    if Plot_011_flag == "Y":
        Plot011(f1)

    if Plot_012_flag == "Y":
        Plot012(f1)

    if Plot_013_flag == "Y":
        Plot013(f1)

    if Plot_014_flag == "Y":
        Plot014(f1)

    if Plot_015_flag == "Y":
        Plot015(f1)


    if Plot_020_flag == "Y":
        Plot020(f1)

    if Plot_020B_flag == "Y":
        Plot020B(f1)
 
    if Plot_021_flag == "Y":
        Plot021(f1)

    if Plot_021B_flag == "Y":
        Plot021B(f1)

    if Plot_022_flag == "Y":
        Plot022(f1)

    if Plot_022B_flag == "Y":
        Plot022B(f1)


    if Plot_030_flag == "Y":
        Plot030(f1)

    if Plot_031_flag == "Y":
        Plot031(f1)

    if Plot_032_flag == "Y":
        Plot032(f1)
    
    if Plot_033_flag == "Y":
        Plot033(f1)

    if Plot_034_flag == "Y":
        Plot034(f1)

    if Plot_035_flag == "Y":
        Plot035(f1)

    if Plot_036_flag == "Y":
        Plot036(f1)

    if Plot_037_flag == "Y":
        Plot037(f1)

    if Plot_038_flag == "Y":
        Plot038(f1)

    if Plot_039_flag == "Y":
        Plot039(f1)

    if Plot_040_flag == "Y":
        Plot040(f1)

    if Plot_041_flag == "Y":
        Plot041(f1)

    if Plot_042_flag == "Y":
        Plot042(f1)

    if Plot_043_flag == "Y":
        Plot043(f1)

    if Plot_044_flag == "Y":
        Plot044(f1)

    if Plot_045_flag == "Y":
        Plot045(f1)

    if Plot_046_flag == "Y":
        Plot046(f1)

    if Plot_047_flag == "Y":
        Plot047(f1)

    if Plot_048_flag == "Y":
        Plot048(f1)

    if Plot_049_flag == "Y":
        Plot049(f1)

    if Plot_050_flag == "Y":
        Plot050(f1)

    if Plot_051_flag == "Y":
        Plot051(f1)

    if Plot_052_flag == "Y":
        Plot052(f1)


        

print("\nDone\n")

# %%
#

# %%
#
# https://data.sdss.org/datamodel/files/APOGEE_ASPCAP/APRED_VERS/ASPCAP_VERS/allStar.html
#
#Sort and display data columns
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 2000)

df_Apogee .columns.sort_values().tolist()
